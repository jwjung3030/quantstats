# %% [markdown]
# <a href="https://colab.research.google.com/github/jwjung3030/quantstats/blob/main/quantstats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 성과지표
# https://pypi.org/project/QuantStats/

# %%
pip -q install quantstats --upgrade --no-cache-dir
# Out:
#      |████████████████████████████████| 6.3 MB 12.4 MB/s
# ...

# %%
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
stock = qs.utils.download_returns('SPY')

qs.reports.full(stock)
# Out:
# [Performance Metrics]
#
#                            Strategy
# -------------------------  ----------
# Start Period               1993-01-29
# End Period                 2021-10-15
# Risk-Free Rate             0.0%
# Time in Market             100.0%
#
# Cumulative Return          1,633.73%
# CAGR﹪                     10.44%
#
# Sharpe                     0.62
# Smart Sharpe               0.57
# Sortino                    0.89
# Smart Sortino              0.81
# Sortino/√2                 0.63
# Smart Sortino/√2           0.57
# Omega                      1.13
#
# Max Drawdown               -55.19%
# Longest DD Days            2404
# Volatility (ann.)          18.75%
# Calmar                     0.19
# Skew                       -0.05
# Kurtosis                   12.15
#
# Expected Daily %           0.04%
# Expected Monthly %         0.83%
# Expected Yearly %          10.34%
# Kelly Criterion            6.13%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -1.9%
# ...
